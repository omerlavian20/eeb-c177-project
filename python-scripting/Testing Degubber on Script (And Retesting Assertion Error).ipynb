# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.core.debugger import set_trace


#input file to analyze, column that want to compare other columns to, and list of columns that want to compare to the original column
def multiple_corrs_excel(filename, colx, coly):
    '''
    Computes correlation coefficients of a list of columns in an Excel file to one particular column. Also creates a plot for each correlation.
    
    ----------
    Example:
    >>>multiple_corrs_excel("Spam_Data.xlsx", "Spam Consumption Frequency", ["Spam Quality", "Love for Eggs", "Frequency of Farts in Your General Direction"])
    The correlation coefficient of Spam Conspumption Frequency and Spam Quality is 0.75.
    The correlation coefficient of Spam Consumption Frequency and Love for Eggs is 0.84.
    The correlation coefficient of Spam Consumption Frequency and Frequency of Farts in Your General Direction is 1.00.
    
    '''
    
    set_trace()
    assert type(coly) == list, "The third input must be in the format of a list."
    #turn an Excel file into a Pandas dataframe
    DataFrame = pd.read_excel(filename)

    #iterate through list of columns, compute Pearson's correlation coefficient of each column with original column, and print out a a statement with the correlation coefficient as well as a plot relating each pair of columns 
    for item in coly:
        y = float(DataFrame[colx].corr(DataFrame[item]))
        print("The correlation coefficient of {} and {} is {number:.{digits}f}. \n".format(colx, item, number = y, digits=2))
        corrplot = plt.plot(DataFrame[colx], DataFrame[item], "bo")
        plt.xlabel(colx)
        plt.ylabel(item)
        plt.title(colx + " vs. " + item)
        plt.show()
    

multiple_corrs_excel("FID_Data.xlsx", "FID (m)", ["DistanceFromCover", "Conspecifics Present"])
# Out:
# > <ipython-input-5-948884a73a40>(22)multiple_corrs_excel()
#      20
#      21     set_trace()
# ---> 22     assert type(coly) == list, "The third input must be in the format of a list."
#      23     #turn an Excel file into a Pandas dataframe
#      24     DataFrame = pd.read_excel(filename)
#
# ipdb> type(coly)
# <class 'list'>
# ipdb> coly
# ['DistanceFromCover', 'Conspecifics Present']
# ipdb> n
# > <ipython-input-5-948884a73a40>(24)multiple_corrs_excel()
#      22     assert type(coly) == list, "The third input must be in the format of a list."
#      23     #turn an Excel file into a Pandas dataframe
# ---> 24     DataFrame = pd.read_excel(filename)
#      25
#      26     #iterate through list of columns, compute Pearson's correlation coefficient of each column with original column, and print out a a statement with the correlation coefficient as well as a plot relating each pair of columns
#
# ipdb> n
# > <ipython-input-5-948884a73a40>(27)multiple_corrs_excel()
#      25
#      26     #iterate through list of columns, compute Pearson's correlation coefficient of each column with original column, and print out a a statement with the correlation coefficient as well as a plot relating each pair of columns
# ---> 27     for item in coly:
#      28         y = float(DataFrame[colx].corr(DataFrame[item]))
#      29         print("The correlation coefficient of {} and {} is {number:.{digits}f}. \n".format(colx, item, number = y, digits=2))
#
# ipdb> n
# > <ipython-input-5-948884a73a40>(28)multiple_corrs_excel()
#      26     #iterate through list of columns, compute Pearson's correlation coefficient of each column with original column, and print out a a statement with the correlation coefficient as well as a plot relating each pair of columns
#      27     for item in coly:
# ---> 28         y = float(DataFrame[colx].corr(DataFrame[item]))
#      29         print("The correlation coefficient of {} and {} is {number:.{digits}f}. \n".format(colx, item, number = y, digits=2))
#      30         corrplot = plt.plot(DataFrame[colx], DataFrame[item], "bo")
#
# ipdb> n
# > <ipython-input-5-948884a73a40>(29)multiple_corrs_excel()
#      27     for item in coly:
#      28         y = float(DataFrame[colx].corr(DataFrame[item]))
# ---> 29         print("The correlation coefficient of {} and {} is {number:.{digits}f}. \n".format(colx, item, number = y, digits=2))
#      30         corrplot = plt.plot(DataFrame[colx], DataFrame[item], "bo")
#      31         plt.xlabel(colx)
#
# ipdb> n
# The correlation coefficient of FID (m) and DistanceFromCover is -0.07.
#
# > <ipython-input-5-948884a73a40>(30)multiple_corrs_excel()
#      28         y = float(DataFrame[colx].corr(DataFrame[item]))
#      29         print("The correlation coefficient of {} and {} is {number:.{digits}f}. \n".format(colx, item, number = y, digits=2))
# ---> 30         corrplot = plt.plot(DataFrame[colx], DataFrame[item], "bo")
#      31         plt.xlabel(colx)
#      32         plt.ylabel(item)
#
# ipdb> n
# > <ipython-input-5-948884a73a40>(31)multiple_corrs_excel()
#      29         print("The correlation coefficient of {} and {} is {number:.{digits}f}. \n".format(colx, item, number = y, digits=2))
#      30         corrplot = plt.plot(DataFrame[colx], DataFrame[item], "bo")
# ---> 31         plt.xlabel(colx)
#      32         plt.ylabel(item)
#      33         plt.title(colx + " vs. " + item)
# ipdb> n
# > <ipython-input-5-948884a73a40>(32)multiple_corrs_excel()
#      30         corrplot = plt.plot(DataFrame[colx], DataFrame[item], "bo")
#      31         plt.xlabel(colx)
# ---> 32         plt.ylabel(item)
#      33         plt.title(colx + " vs. " + item)
#      34         plt.show()
#
# ipdb> n
# > <ipython-input-5-948884a73a40>(33)multiple_corrs_excel()
#      31         plt.xlabel(colx)
#      32         plt.ylabel(item)
# ---> 33         plt.title(colx + " vs. " + item)
#      34         plt.show()
#      35
#
# ipdb> n
# > <ipython-input-5-948884a73a40>(34)multiple_corrs_excel()
#      32         plt.ylabel(item)
#      33         plt.title(colx + " vs. " + item)
# ---> 34         plt.show()
#      35
#      36
#
# ipdb> n
# > <ipython-input-5-948884a73a40>(27)multiple_corrs_excel()
#      25
#      26     #iterate through list of columns, compute Pearson's correlation coefficient of each column with original column, and print out a a statement with the correlation coefficient as well as a plot relating each pair of columns
# ---> 27     for item in coly:
#      28         y = float(DataFrame[colx].corr(DataFrame[item]))
#      29         print("The correlation coefficient of {} and {} is {number:.{digits}f}. \n".format(colx, item, number = y, digits=2))
#
# ipdb> n
# > <ipython-input-5-948884a73a40>(28)multiple_corrs_excel()
#      26     #iterate through list of columns, compute Pearson's correlation coefficient of each column with original column, and print out a a statement with the correlation coefficient as well as a plot relating each pair of columns
#      27     for item in coly:
# ---> 28         y = float(DataFrame[colx].corr(DataFrame[item]))
#      29         print("The correlation coefficient of {} and {} is {number:.{digits}f}. \n".format(colx, item, number = y, digits=2))
#      30         corrplot = plt.plot(DataFrame[colx], DataFrame[item], "bo")
#
# ipdb> n
# > <ipython-input-5-948884a73a40>(29)multiple_corrs_excel()
#      27     for item in coly:
#      28         y = float(DataFrame[colx].corr(DataFrame[item]))
# ---> 29         print("The correlation coefficient of {} and {} is {number:.{digits}f}. \n".format(colx, item, number = y, digits=2))
#      30         corrplot = plt.plot(DataFrame[colx], DataFrame[item], "bo")
#      31         plt.xlabel(colx)
#
# ipdb> n
# The correlation coefficient of FID (m) and Conspecifics Present is -0.13.
#
# > <ipython-input-5-948884a73a40>(30)multiple_corrs_excel()
#      28         y = float(DataFrame[colx].corr(DataFrame[item]))
#      29         print("The correlation coefficient of {} and {} is {number:.{digits}f}. \n".format(colx, item, number = y, digits=2))
# ---> 30         corrplot = plt.plot(DataFrame[colx], DataFrame[item], "bo")
#      31         plt.xlabel(colx)
#      32         plt.ylabel(item)
#
# ipdb> n
# > <ipython-input-5-948884a73a40>(31)multiple_corrs_excel()
#      29         print("The correlation coefficient of {} and {} is {number:.{digits}f}. \n".format(colx, item, number = y, digits=2))
#      30         corrplot = plt.plot(DataFrame[colx], DataFrame[item], "bo")
# ---> 31         plt.xlabel(colx)
#      32         plt.ylabel(item)
#      33         plt.title(colx + " vs. " + item)
#
# ipdb> n
# > <ipython-input-5-948884a73a40>(32)multiple_corrs_excel()
#      30         corrplot = plt.plot(DataFrame[colx], DataFrame[item], "bo")
#      31         plt.xlabel(colx)
# ---> 32         plt.ylabel(item)
#      33         plt.title(colx + " vs. " + item)
#      34         plt.show()
#
# ipdb> n
# > <ipython-input-5-948884a73a40>(33)multiple_corrs_excel()
#      31         plt.xlabel(colx)
#      32         plt.ylabel(item)
# ---> 33         plt.title(colx + " vs. " + item)
#      34         plt.show()
#      35
# ipdb> n
# > <ipython-input-5-948884a73a40>(34)multiple_corrs_excel()
#      32         plt.ylabel(item)
#      33         plt.title(colx + " vs. " + item)
# ---> 34         plt.show()
#      35
#      36
#
# ipdb> n
# > <ipython-input-5-948884a73a40>(27)multiple_corrs_excel()
#      25
#      26     #iterate through list of columns, compute Pearson's correlation coefficient of each column with original column, and print out a a statement with the correlation coefficient as well as a plot relating each pair of columns
# ---> 27     for item in coly:
#      28         y = float(DataFrame[colx].corr(DataFrame[item]))
#      29         print("The correlation coefficient of {} and {} is {number:.{digits}f}. \n".format(colx, item, number = y, digits=2))
#
# ipdb> n
# --Return--
# None
# > <ipython-input-5-948884a73a40>(27)multiple_corrs_excel()
#      25
#      26     #iterate through list of columns, compute Pearson's correlation coefficient of each column with original column, and print out a a statement with the correlation coefficient as well as a plot relating each pair of columns
# ---> 27     for item in coly:
#      28         y = float(DataFrame[colx].corr(DataFrame[item]))
#      29         print("The correlation coefficient of {} and {} is {number:.{digits}f}. \n".format(colx, item, number = y, digits=2))
